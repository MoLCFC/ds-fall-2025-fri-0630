# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.

import pandas as pd
import numpy as np

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = 'food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
df_food.shape
# Out:
# (125, 61)

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          123 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.

df_food = df_food[['calories_day', 'weight', 'Gender']].copy()

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.

df_food.isna().sum()
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.

df_food = df_food.dropna()

print(df_food)
# Out:
#      calories_day                    weight  Gender
# 1             3.0                       155       1
# 2             4.0  I'm not answering this.        1
# 3             3.0             Not sure, 240       1
# 4             2.0                       190       1
# 5             3.0                       190       1
# ..            ...                       ...     ...
# 118           3.0                       140       1
# 119           3.0                       185       2
# 120           4.0                       156       1
# 121           2.0                       180       1
# 123           4.0                       135       2
#
# [104 rows x 3 columns]

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.

df_food['calories_day'] = pd.to_numeric(df_food['calories_day'], errors='coerce')
df_food = df_food.dropna(subset=['calories_day'])

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!

df_food.to_csv('cleaned_food_data.csv', index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
df_salary = pd.read_csv('ask_a_manager_salary_survey_2021.tsv', delimiter='\t')

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.

len(df_salary)

#28062
# Out:
# 28062

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.

df_salary.dtypes
# Out:
# timestamp                   object
# age                         object
# industry                    object
# title                       object
# title_context               object
# salary                      object
# additional_compensation    float64
# currency                    object
# other_currency              object
# salary_context              object
# country                     object
# state                       object
# city                        object
# years_exp_overall           object
# years_exp_field             object
# education                   object
# gender                      object
# race                        object
# dtype: object

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race

df_salary.columns = [
    'timestamp', 'age', 'industry', 'title', 'title_context', 'salary', 'additional_compensation',
    'currency', 'other_currency', 'salary_context', 'country', 'state', 'city',
    'years_exp_overall', 'years_exp_field', 'education', 'gender', 'race'
]

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.

df_salary['industry'].value_counts()
# Out:
# industry
# Computing or Tech                          4699
# Education (Higher Education)               2464
# Nonprofits                                 2419
# Health care                                1896
# Government and Public Administration       1889
#                                            ...
# Gaming (Gambling)                             1
# Regulatory Affairs- nutraceuticals            1
# Manufacturing : corporate admin support       1
# Real Estate Investment Support                1
# Wine & Spirits                                1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)

df_salary_tech = df_salary[df_salary['industry'] == 'Computing or Tech']

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 

df_salary_tech['industry'].unique()
# Out:
# array(['Computing or Tech'], dtype=object)

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!

df_salary_tech_usd = df_salary_tech[df_salary_tech['currency'] == 'USD']

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.

df_salary_tech_usd['country'].value_counts()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Pakistan                       1
# Puerto Rico                    1
# America                        1
# Uniyed states                  1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.

us_variants = [
    'United States', 'US', 'U.S.', 'United States of America', 'America'
]
df_salary_tech_usd.loc[
    df_salary_tech_usd['country'].isin(us_variants), 'country'
] = 'US'

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.

df_salary_tech_usd['country'].value_counts()
# Out:
# country
# US                2187
# USA               1222
# United States       68
# Usa                 59
# USA                 56
#                   ...
# Mexico               1
# Canada               1
# ISA                  1
# singapore            1
# Burma                1
# Name: count, Length: 72, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.

valid_countries = ['US', 'Canada', 'Mexico', 'UK', 'Ireland', 'Germany', 'France', 'India', 'Australia']
df_salary_tech_usd = df_salary_tech_usd[df_salary_tech_usd['country'].isin(valid_countries)]

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.

df_salary_tech_usd['country'].value_counts()
# Out:
# country
# US           2187
# Canada          4
# Australia       2
# India           2
# France          2
# Mexico          1
# Name: count, dtype: int64

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
df_salary_tech_usd = df_salary_tech_usd[pd.to_numeric(df_salary_tech_usd['salary'], errors='coerce').notnull()]
df_salary_tech_usd['salary'] = df_salary_tech_usd['salary'].astype(float)

df_salary_tech_usd.groupby('state')['salary'].agg(['min', 'mean', 'max']).sort_values('mean', ascending=False)
# Out:
# C:\Users\mwghe\AppData\Local\Temp\ipykernel_6752\1791718968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_tech_usd['salary'] = df_salary_tech_usd['salary'].astype(float)
#                             min           mean       max
# state
# Connecticut            230000.0  230000.000000  230000.0
# California, Oregon     200000.0  200000.000000  200000.0
# California, Colorado   176000.0  176000.000000  176000.0
# Idaho                  170000.0  170000.000000  170000.0
# California                  0.0  158218.790476  350000.0
# District of Columbia    59000.0  150714.285714  195000.0
# New York                45000.0  147962.031250  590000.0
# Kansas                  96000.0  142500.000000  167000.0
# ...

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
df_salary_tech_usd = df_salary_tech_usd.copy()
df_salary_tech_usd.loc[:, 'salary'] = (
    df_salary_tech_usd['salary']
    .astype(str)
    .str.replace(',', '', regex=False)
    .str.replace('$', '', regex=False)
)
df_salary_tech_usd.loc[:, 'salary'] = pd.to_numeric(df_salary_tech_usd['salary'], errors='coerce')
# Out:
# C:\Users\mwghe\AppData\Local\Temp\ipykernel_6752\1377304911.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0.0' '240.0' '72.0' '130.0' '80.0' '0.0' '100000.0' '287000.0' '57000.0'
#  '104000.0' '93000.0' '85000.0' '156000.0' '104203.0' '144000.0' '63000.0'
#  '142000.0' '190000.0' '43000.0' '136000.0' '55000.0' '144055.0' '70000.0'
#  '101000.0' '113000.0' '200000.0' '81000.0' '75000.0' '165000.0'
#  '125000.0' '171000.0' '135000.0' '85000.0' '104000.0' '152000.0'
#  '96500.0' '220000.0' '134000.0' '105000.0' '198000.0' '102000.0'
#  '115000.0' '172000.0' '45760.0' '160000.0' '80000.0' '96160.0' '117000.0'
#  '70000.0' '210000.0' '44900.0' '24000.0' '135200.0' '127000.0' '165000.0'
#  '162000.0' '280000.0' '112500.0' '165000.0' '75000.0' '240000.0'
#  '180000.0' '55000.0' '162000.0' '200000.0' '80000.0' '72000.0' '100000.0'
#  '142000.0' '142000.0' '128000.0' '195700.0' '200000.0' '80000.0'
# ...

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
df_salary_tech_usd = df_salary_tech_usd.copy()
df_salary_tech_usd.loc[:, 'salary'] = (
    df_salary_tech_usd['salary']
    .astype(str)
    .str.replace(',', '', regex=False)
    .str.replace('$', '', regex=False)
)
df_salary_tech_usd.loc[:, 'salary'] = pd.to_numeric(df_salary_tech_usd['salary'], errors='coerce')

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
df_salary_tech_usd_recent = df_salary_tech_usd.copy()


df_salary_tech_usd_recent['timestamp'] = pd.to_datetime(
    df_salary_tech_usd_recent['timestamp'], errors='coerce'
)

# Keep only 2021 and 2022
df_salary_tech_usd_recent = df_salary_tech_usd_recent[
    df_salary_tech_usd_recent['timestamp'].dt.year.isin([2021, 2022])
]


salary_stats_recent = (
    df_salary_tech_usd_recent
    .groupby('state')['salary']
    .agg(['min', 'mean', 'max'])
    .sort_values('mean', ascending=False)
)

salary_stats_recent
# Out:
#                             min           mean       max
# state
# Connecticut            230000.0       230000.0  230000.0
# California, Oregon     200000.0       200000.0  200000.0
# California, Colorado   176000.0       176000.0  176000.0
# Idaho                  170000.0       170000.0  170000.0
# California                  0.0  159067.048077  350000.0
# District of Columbia    59000.0  150714.285714  195000.0
# New York                45000.0  149278.888889  590000.0
# Kansas                  96000.0       142500.0  167000.0
# Massachusetts           49920.0  132982.045455  400000.0
# Washington                 72.0  131519.780488  300000.0
# New Jersey             100000.0       130000.0  170000.0
# Virginia                70000.0  127367.869565  378000.0
# Nevada                 107100.0       124550.0  142000.0
# Georgia                 29120.0       123666.0  240000.0
# Oregon                  16200.0       121252.0  230000.0
# ...

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
# ensure datetime
ts = pd.to_datetime(df_salary_clean['timestamp'], errors='coerce')

# filter 2021–2022 using the datetime Series
df_salary_clean = df_salary_clean.loc[ts.dt.year.isin([2021, 2022])].copy()

# recompute stats
salary_stats = (
    df_salary_clean.groupby('state')['salary']
    .agg(['min', 'mean', 'max'])
    .sort_values('mean', ascending=False)
)
salary_stats
# Out:
#                                                        min      mean     max
# state
# Michigan, Texas, Washington                         340000  340000.0  340000
# Indiana, Ohio                                       245000  245000.0  245000
# Colorado, Nevada                                    190000  190000.0  190000
# California, Montana                                 185000  185000.0  185000
# California, Texas                                   185000  185000.0  185000
# ...                                                    ...       ...     ...
# District of Columbia, Washington                     35000   35000.0   35000
# Delaware, Pennsylvania                               35000   35000.0   35000
# Alabama, California                                  29120   29120.0   29120
# District of Columbia, Maryland, Pennsylvania, V...   27040   27040.0   27040
# Maryland, New York                                   14000   14000.0   14000
#
# [131 rows x 3 columns]

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
salary_stats.style.format('${:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4bf27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bf27_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_4bf27_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_4bf27_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bf27_level0_row0" class="row_heading level0 row0" >Michigan, Texas, Washington</th>
#       <td id="T_4bf27_row0_col0" class="data row0 col0" >$340,000</td>
#       <td id="T_4bf27_row0_col1" class="data row0 col1" >$340,000</td>
#       <td id="T_4bf27_row0_col2" class="data row0 col2" >$340,000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
single_state = ~salary_stats.index.str.contains(',')
salary_stats_single = salary_stats[single_state]

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
# ensure numeric salary
dfq = dfq.copy()
dfq['salary'] = pd.to_numeric(dfq['salary'], errors='coerce')
dfq = dfq[dfq['salary'].notna()].copy()
dfq['salary'] = dfq['salary'].astype('float64')

# quantiles + counts
qs = [0.00, 0.05, 0.25, 0.50, 0.75, 0.95, 1.00]
q = dfq.groupby('state')['salary'].quantile(q=qs)
quantiles = q.unstack(-1)
quantiles.columns = ['0%', '5%', '25%', '50%', '75%', '95%', '100%']
counts = dfq.groupby('state')['salary'].size().rename('Count')

salary_quantiles_df = (
    pd.concat([quantiles, counts], axis=1)
      .sort_values('50%', ascending=False)
)
salary_quantiles_df
# Out:
#                            0%       5%      25%       50%       75%  \
# state
# California                0.0  42000.0  72000.0  100796.0  147000.0
# Washington               72.0  39980.0  65000.0   90924.0  135000.0
# District of Columbia     40.0  48000.0  66900.0   90000.0  125000.0
# New York                 80.0  40904.0  64480.0   90000.0  127000.0
# Massachusetts           155.0  42000.0  64000.0   86000.0  120000.0
# Maryland                  0.0  40050.0  60000.0   82000.0  110000.0
# Connecticut               0.0  33702.5  61250.0   81900.0  100000.0
# Virginia                 57.0  37380.0  58750.0   80616.5  115000.0
# Delaware              35000.0  40480.0  57546.5   80145.0  105500.0
# Oregon                    0.0  36400.0  58200.0   78000.0  110000.0
# Illinois                  0.0  37440.0  56000.0   76000.0  110000.0
# Colorado                 65.0  38888.0  58000.0   76000.0  111000.0
# Texas                     0.0  35041.6  55000.0   75700.0  110000.0
# ...
